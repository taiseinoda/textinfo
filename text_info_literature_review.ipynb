# %% [markdown]
# Here are the research questions and uses of textual information for each paper:
#
# *   **Hanley, K., Hoberg, G. (2012). Litigation risk, strategic disclosure and the underpricing of initial public offerings; Hanley, K., Hoberg, G. (2010). The information content of IPO prospectuses; Hoberg, G., Phillips, G. (2010). Product market synergies and competition in mergers and acquisitions: a text-based analysis; Jegadeesh, N., Wu, A. (2011). Word power: a new approach for content analysis.**
#     *   **Research Questions:** These papers explore various aspects of financial markets using textual analysis. The 2012 paper likely investigates how litigation risk and strategic disclosure in IPO prospectuses relate to IPO underpricing. The 2010 Hanley and Hoberg paper examines the information content of IPO prospectuses. The 2010 Hoberg and Phillips paper studies product market synergies and competition in mergers and acquisitions. The 2011 Jegadeesh and Wu paper proposes a new method for content analysis.
#     *   **Use of Textual Information:** These studies utilize the text from IPO prospectuses to assess disclosure strategies and information content, potentially through tone and risk-related language. The Hoberg and Phillips paper uses textual analysis to quantify synergies and competition in M\&A deals. Jegadeesh and Wu's work focuses on developing a new approach to quantify the content of financial texts.
#
# *   **Paper from "1-s2.0-S0304405X13001761-main.pdf".**
#     *   **Research Question:** This paper investigates the acquiring manager's decision to abandon a proposed transaction.
#     *   **Use of Textual Information:** The study uses media attention and tone as variables, suggesting textual analysis of news coverage related to the transactions to quantify these aspects.
#
# *   **Jegadeesh, N., Wu, A. (2013). Word power: a new approach for content analysis.**
#     *   **Research Questions:** This paper examines how investors interpret descriptive information and whether they efficiently incorporate it into prices. It introduces a new content analysis approach and explores its application in finance. Specific questions include the relationship between the tone of IPO prospectuses and underpricing, the generalizability of term weights across contexts, and the timeliness of market reactions to 10-K tone. It also assesses the importance of word list accuracy and completeness.
#     *   **Use of Textual Information:** The paper uses content analysis to quantify the tone of descriptive information in annual reports and IPO prospectuses. It develops and estimates term weights for words based on market reactions around 10-K filings. It then applies these weights to calculate tone scores for IPO prospectuses to predict underpricing. The Loughran and McDonald (LM) word list is used in this process.
#
# *   **Tetlock, P.C. (2007). All the news that's fit to reprint: do investors react to stale information?**
#     *   **Research Question:** This paper investigates the relationship between the tone of the "Abreast of the Market" column in the Wall Street Journal and stock market returns and trading volumes.
#     *   **Use of Textual Information:** The study performs textual analysis on the WSJ column, using word lists (like the Harvard IV-4 dictionary) to quantify the tone (proportion of positive and negative words) and examines its correlation with market activity.
#
# *   **Tetlock, P.C., Saar-Tsechansky, M., Macskassy, S. (2008). More than words: quantifying language to measure firms’ fundamentals.**
#     *   **Research Question:** This paper examines how the market reacts to the tone of news stories and explores whether linguistic content can be used to understand firms' fundamentals and predict stock returns, volatility, or trading volume.
#     *   **Use of Textual Information:** The study uses content analysis to quantify the tone of news articles and analyzes its relationship with various financial market indicators.
#
# *   **Feldman, R., Govindaraj, S., Livnat, J., Segal, B. (2010). Management's discussion and analysis: Readability, overall tone, and risk disclosure.**
#     *   **Research Question:** This paper examines the tone of 10-K reports and its association with stock returns, hypothesizing a linear relationship between them and the proportion of positive and negative words.
#     *   **Use of Textual Information:** The research uses content analysis to measure the tone of 10-K filings by analyzing the frequency of positive and negative words and investigates its correlation with stock returns.
#
# *   **Loughran, T., McDonald, B. (2011). When is a liability not a liability? textual analysis, dictionaries, and 10-ks.**
#     *   **Research Questions:** This paper investigates the tone and sentiment of corporate 10-K reports using textual analysis. It also questions the suitability of general-purpose word lists (like Harvard IV-4) for business contexts and proposes new, finance-specific word lists.
#     *   **Use of Textual Information:** The study employs textual analysis on 10-K filings, using a bag-of-words approach and various word lists (including their own) to quantify tone and sentiment. They exclude tables and exhibits from their primary analysis. The paper also recommends the use of term weighting.
#
# *   **Das, S., Chen, M. (2007). Yahoo! for Amazon: Opinion extraction from small talk on the web.**
#     *   **Research Question:** This paper aims to extract investor sentiment from posts on Yahoo! Finance message boards to predict stock return movements.
#     *   **Use of Textual Information:** The study applies machine learning classifiers (like naïve Bayes and vector distance) to the text of online investor messages to extract and quantify sentiment.
#
# *   **Antweiler, W., Frank, M.Z. (2004). Is all that talk just noise? The information content of Internet stock message boards.**
#     *   **Research Question:** This paper investigates the information content of online stock message boards and whether the opinions expressed can predict stock returns.
#     *   **Use of Textual Information:** The study uses textual analysis to extract sentiment from the content of internet stock message board postings and examines its relationship with stock market outcomes.
#
# *   **Li, F. (2006). Do stock market investors understand the risk factors disclosed in SEC filings?**
#     *   **Research Question:** This paper examines the relationship between the disclosure of risk and uncertainty in 10-K filings and stock returns, focusing on the frequency of the words "risk" and "uncertainty".
#     *   **Use of Textual Information:** The study uses a simple word count approach, focusing on the occurrences of specific risk-related terms within 10-K filings and analyzing their association with stock returns.
#
# *   **Hwang, B.-H., Kim, H.H. (2017). Investor protection and IPO underpricing.**
#     *   **Research Question:** This paper connects the writing quality of financial filings to valuation, specifically in the context of closed-end funds.
#     *   **Use of Textual Information:** The study likely employs readability metrics and other textual features of SEC filings to assess writing quality and its impact on fund valuation.
#
# *   **Paper from "1-s2.0-S0304405X17300193-main.pdf".**
#     *   **Research Question:** This paper investigates the effect of the readability of annual reports on individuals' perceptions of trustworthiness and manager skill, as well as their emotional state.
#     *   **Use of Textual Information:** The study uses an experiment where participants read financial text with varying readability levels, indicating that readability, a textual attribute, is the key variable being manipulated and assessed for its impact on perceptions.
#
# *   **Paper from "1-s2.0-S0304405X18301727-main.pdf".**
#     *   **Research Question:** This paper aims to extract the expertise of board members by analyzing the text of their biographies and likely examines the relationship between this expertise and firm outcomes, potentially in the context of hedge fund activism.
#     *   **Use of Textual Information:** The study performs textual analysis on board member biographies from the NYSE Director’s Database, using keyword searches to identify expertise in areas like academia, accounting, innovation, etc..
#
# *   **Calomiris, C.W., Mamaysky, H. (2019). Fundamentals and beliefs: The informational content of news in good and bad times.**
#     *   **Research Questions:** This paper explores the relationship between news and changes in stock market returns and risks. It investigates what type of news matters and how it is associated with market outcomes. It also considers the appropriate news sources and timeframes for predicting risk and return globally.
#     *   **Use of Textual Information:** The study uses the Thomson Reuters Machine Readable News archive and constructs measures of textual content to analyze their relationship with stock market behavior.
#
# *   **Paper from "1-s2.0-S0304405X19301606-main.pdf".**
#     *   **Research Question:** This paper examines how the loss of monitoring due to local newspaper closures might influence public finance.
#     *   **Use of Textual Information:** While not explicitly detailed in the excerpt, it's highly probable that the study involves analyzing the content and tone of local newspapers before and after closures to assess their role in monitoring and informing about public finance issues.
#
# *   **Luo, M., Wu, A. (2022). Investor sentiment and return predictability: The role of news photos.**
#     *   **Research Questions:** This paper investigates whether news photos contain novel information about investors’ beliefs beyond the text of the news and how these two sources of information interact in relation to market returns.
#     *   **Use of Textual Information:** The study performs textual analysis to measure investor sentiment from news articles (TextPes) and examines its interaction with sentiment derived from photos (PhotoPes) in predicting market returns.
#
# *   **Jeon, Y., McCurdy, T.H., Zhao, X. (2022). News and stock return jumps.**
#     *   **Research Question:** This paper examines how news flows affect the probability, intensity, and return characteristics of individual stock return jumps.
#     *   **Use of Textual Information:** The study analyzes the textual content of the first paragraph of news articles from Factiva using word lists by Loughran and McDonald (2011, 2013) to measure news tone and the percentage of uncertain words.
#
# *   **Kim, J., Park, S.Y. (2023). Impression management and investor communication.**
#     *   **Research Questions:** This paper investigates whether impression management considerations influence investors’ online conversations, particularly their consumption and sharing of quantitative versus qualitative content. It also examines if this leads to the transmission of less informative content.
#     *   **Use of Textual Information:** The study defines quantitative and qualitative articles on Seeking Alpha based on the ratio of numbers to total words in the text. It analyzes which types of articles (quantitative or qualitative) are read more completely and shared more often, relating this to potential impression management by authors.
#
# *   **Bena, J., Ortiz-Molina, H., Simintzi, E. (2022). Board gender diversity and innovation.**
#     *   **Research Question:** This paper investigates the relationship between board gender diversity and firm innovation.
#     *   **Use of Textual Information:** The excerpt provided does not detail the use of textual information. The focus seems to be on patent data to measure innovation.
#
# *   **Li, S., Prabhala, N.R. (2023). Professionals and the dissemination of complex information.**
#     *   **Research Question:** This paper examines how finance professionals process complex information from news by comparing market reactions to original news versus recombinations and reprints.
#     *   **Use of Textual Information:** The study uses textual analysis of Bloomberg news data to determine the novelty of news articles by comparing their content to prior articles about the same firm. This helps classify articles as recombinations or reprints.
#
# *   **Gurun, U.G., Lee, S.H., Stoffman, N. (2024). Does the media affect stock market participation?**
#     *   **Research Questions:** This paper investigates whether connections between firms and the media influence news coverage and examines the broader impact of financial news on stock market participation.
#     *   **Use of Textual Information:** The study collects and analyzes the text of articles from the New York Times and the Wall Street Journal that mention specific firms, focusing on articles that mention only one firm to clearly link content. The content and potentially the tone of these articles are likely analyzed in relation to market participation.
#
# *   **Loughran, T., McDonald, B. (2014). Measuring readability in financial disclosures.**
#     *   **Research Questions:** This paper focuses on defining and measuring readability in financial disclosures, particularly 10-K filings. It examines how readability relates to the incorporation of information into stock prices and whether managers use complexity to obscure poor future earnings.
#     *   **Use of Textual Information:** The study analyzes the text of 10-K documents to calculate readability measures such as the Fog Index and word count.
#
# *   **Fedyk, A. (2023). Front‐Page News: The Effect of News Positioning on Financial Markets.**
#     *   **Research Question:** This paper investigates the causal effect of news article positioning on the Bloomberg terminal (front page vs. non-front page) on financial market attention and reactions.
#     *   **Use of Textual Information:** The study uses machine learning techniques, including topic modeling and deep learning on news headlines, to ensure that front-page and non-front-page articles about significant individual (SI) news do not differ systematically in their content or importance as perceived by the algorithms.
#
# *   **Sautner, Z., van Lent, L., Vilkov, G., Zhang, R. (2023). Firm‐Level Climate Change Exposure.**
#     *   **Research Questions:** This paper aims to develop and validate measures of firm-level climate change exposure using the textual content of earnings conference calls and 10-K reports. It also incorporates a measure of public attention to climate change based on Wall Street Journal news.
#     *   **Use of Textual Information:** The study uses textual analysis of earnings call transcripts and 10-K filings to identify the frequency and context of discussions related to climate change. It also uses the news content of the WSJ on climate change, comparing it to a corpus of authoritative texts.
#
# *   **Bybee, L., Kelly, B., Manela, A., Xiu, D. (2024). Business News and Business Cycles.**
#     *   **Research Questions:** This paper proposes a method to measure the state of the economy by applying topic modeling to the full text of Wall Street Journal articles. It investigates whether news attention to different economic themes can track economic activity and forecast stock market returns and macroeconomic dynamics.
#     *   **Use of Textual Information:** The study applies a topic model (LDA) to a large corpus of WSJ articles to identify underlying economic themes and measures the time-varying attention allocated to each theme. It then analyzes the relationship between these news attention measures and macroeconomic and financial variables.
#
# *   **Bhagwat, V.,стейкхолдер, D.A., образования, R. (2021). Big data in finance research.**
#     *   **Research Questions:** This is an introduction to a special issue on big data in finance research. It defines "big data" in this context, reviews the six papers in the issue, and discusses future research directions. One reviewed paper (Li et al., 2021) aims to measure corporate culture from earnings call transcripts, while another (Benamar et al., 2021) uses processed clickstream data to measure information demand.
#     *   **Use of Textual Information:** The introduction highlights papers that use textual data from earnings calls to measure corporate culture and mentions the processing of unstructured data (like clickstreams) by vendors to derive structured measures relevant to finance.
#
# *   **Burnett, S., маркетинг, J., образования, D. (2023). AI Readership and Corporate Disclosure Strategy.**
#     *   **Research Questions:** This study investigates how firms adjust their disclosure strategies in response to the increasing use of AI for processing financial filings. It examines the relationship between the "machine readability" of filings and the extent to which they are downloaded by machines (a proxy for AI readership).
#     *   **Use of Textual Information:** The study uses machine readability metrics to assess how easily filings can be processed by AI. It uses the volume of machine downloads of SEC filings as a proxy for AI readership and relates this to the readability of the documents. It also references prior work using textual analysis of disclosures to predict financial outcomes.
#
# *   **Han, B., Hirshleifer, D., Li, S.Y., Teoh, S.H. (2024). Limited Attention and Social Learning of Earnings News.**
#     *   **Research Question:** This paper investigates the social transmission of earnings news among investors and how this process affects market reactions.
#     *   **Use of Textual Information:** While the primary focus is on social learning, the study is based on the dissemination of earnings news, which originates from textual releases. The paper implicitly relies on the processing and understanding of this textual information by investors.
#
# *   **Barinov, A., Luo, M., Taddy, M. (2024). The Language of Finance.**
#     *   **Research Question:** This paper aims to measure the sentiment toward finance expressed in written language across different languages and time.
#     *   **Use of Textual Information:** The study uses textual analysis of sentences mentioning finance in books to quantify the sentiment (positive or negative context) towards finance in each language and year.
#
# *   **Brown, S.V., Tucker, A.L. (2011). Financial constraints and firms’ disclosure choices: Evidence from MD&A complexity.**
#     *   **Research Question:** This paper investigates the relationship between firms' financial constraints and the complexity of their disclosures in the Management’s Discussion and Analysis (MD&A) section of 10-K filings. It develops text-based measures of financial constraints by analyzing the language used in the Liquidity and Capital Resources subsection.
#     *   **Use of Textual Information:** The study extracts and analyzes the text of the MD&A section, particularly the Liquidity and Capital Resources subsection, to identify language indicative of financial constraints using keyword searches and synonym identification.
#
# *   ** цінності, G.J., освіти, F., маркетингу, N. (2014). Speculation in the News.**
#     *   **Research Question:** This paper examines the determinants of accuracy in business press reporting, particularly in the context of merger rumors. It investigates whether the characteristics of the news text and the journalists influence the accuracy of the reported information.
#     *   **Use of Textual Information:** The study analyzes the text of merger rumors, focusing on the use of weak modal words as an indicator of speculation. It also collects biographical information about the journalists who authored the rumors and relates these characteristics to the accuracy of their reporting.
#
# *   **Soo, C.K. (2018). Quantifying sentiment with news media across local housing markets.**
#     *   **Research Question:** This paper aims to quantify sentiment towards local housing markets using news media and investigate its relationship with house prices. It also explores whether media sentiment reflects unobserved fundamentals or pure sentiment.
#     *   **Use of Textual Information:** The study performs textual analysis on a large sample of local housing news articles, using a dictionary-based method to quantify the frequency of positive and negative words and measure housing media sentiment. It also analyzes the content of articles discussing housing fundamentals.
#
# *   **новини, А., фондовий ринок, D. (2018). Information Trading and Stock Market Volatility.**
#     *   **Research Question:** This paper aims to isolate the impact of relevant news on stock market volatility by systematically identifying firm-specific events reported in the news.
#     *   **Use of Textual Information:** The study employs two commercial information extraction platforms (VIP and Ravenpack) that use supervised learning and natural language processing to identify company-relevant events in news articles from Dow Jones Newswire and other sources. These platforms analyze the text to identify events like product launches, lawsuits, and earnings news, even when company names are not explicitly mentioned. The paper then examines stock return volatility around these identified news events.
#
# *   **Engelberg, J.E., McLean, R.D., Pontiff, J. (2021). Information acquisition and asset prices.**
#     *   **Research Question:** This paper investigates the information acquisition skills of institutions by analyzing their trading behavior around the first public release of news. It examines whether institutions trade on private information ahead of news releases or react quickly to public news. It also analyzes the relationship between the tone of the news, institutional trading, and stock price reactions.
#     *   **Use of Textual Information:** The study uses textual analysis to quantify the tone of news articles (frequency of positive and negative words) from a comprehensive news database. It then links the tone of unanticipated news releases to institutional trading activity and stock price movements around the time of the news.
#     *
